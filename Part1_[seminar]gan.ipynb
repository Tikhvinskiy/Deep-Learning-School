# %% [markdown]
# <p style="align: center;"><img align=center src="https://drive.google.com/uc?export=view&id=1I8kDikouqpH4hf7JBiSYAeNT2IO52T-T" width=600 height=480/></p>
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Семинар. Весна 2021</b></h3>
#
# # Generative adversarial networks

# %% [markdown]
# В этом ноутбуке мы попробуем обучить GAN генерировать морды кошек из случайного шума. Датасет с кошками взят отсюда:
# https://www.kaggle.com/spandan2/cats-faces-64x64-for-generative-models

# %%
import os
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as tt
import torch
import torch.nn as nn
import cv2
from tqdm.notebook import tqdm
import torch.nn.functional as F
from torchvision.utils import save_image
from torchvision.utils import make_grid
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style='darkgrid', font_scale=1.2)

# %%
# !unzip archive.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: cats/cats/5499.jpg
#   inflating: cats/cats/55.jpg
#   inflating: cats/cats/550.jpg
#   inflating: cats/cats/5500.jpg
#   inflating: cats/cats/5501.jpg
#   inflating: cats/cats/5502.jpg
#   inflating: cats/cats/5503.jpg
#   inflating: cats/cats/5504.jpg
#   inflating: cats/cats/5505.jpg
#   inflating: cats/cats/5506.jpg
#   inflating: cats/cats/5507.jpg
#   inflating: cats/cats/5508.jpg
#   inflating: cats/cats/5509.jpg
#   inflating: cats/cats/551.jpg
#   inflating: cats/cats/5510.jpg
#   inflating: cats/cats/5511.jpg
#   inflating: cats/cats/5512.jpg
#   inflating: cats/cats/5513.jpg
#   inflating: cats/cats/5514.jpg
#   inflating: cats/cats/5515.jpg
#   inflating: cats/cats/5516.jpg
#   inflating: cats/cats/5517.jpg
#   inflating: cats/cats/5518.jpg
#   inflating: cats/cats/5519.jpg
#   inflating: cats/cats/552.jpg
#   inflating: cats/cats/5520.jpg
#   inflating: cats/cats/5521.jpg
#   inflating: cats/cats/5522.jpg
#   inflating: cats/cats/5523.jpg
#   inflating: cats/cats/5524.jpg
#   inflating: cats/cats/5525.jpg
#   inflating: cats/cats/5526.jpg
#   inflating: cats/cats/5527.jpg
#   inflating: cats/cats/5528.jpg
#   inflating: cats/cats/5529.jpg
#   inflating: cats/cats/553.jpg
#   inflating: cats/cats/5530.jpg
#   inflating: cats/cats/5531.jpg
#   inflating: cats/cats/5532.jpg
#   inflating: cats/cats/5533.jpg
#   inflating: cats/cats/5534.jpg
#   inflating: cats/cats/5535.jpg
#   inflating: cats/cats/5536.jpg
#   inflating: cats/cats/5537.jpg
#   inflating: cats/cats/5538.jpg
#   inflating: cats/cats/5539.jpg
#   inflating: cats/cats/554.jpg
#   inflating: cats/cats/5540.jpg
#   inflating: cats/cats/5541.jpg
#   inflating: cats/cats/5542.jpg
#   inflating: cats/cats/5543.jpg
#   inflating: cats/cats/5544.jpg
#   inflating: cats/cats/5545.jpg
#   inflating: cats/cats/5546.jpg
#   inflating: cats/cats/5547.jpg
#   inflating: cats/cats/5548.jpg
#   inflating: cats/cats/5549.jpg
#   inflating: cats/cats/555.jpg
#   inflating: cats/cats/5550.jpg
#   inflating: cats/cats/9942.jpg
#   inflating: cats/cats/9943.jpg
#   inflating: cats/cats/9944.jpg
#   inflating: cats/cats/9945.jpg
#   inflating: cats/cats/9946.jpg
#   inflating: cats/cats/9947.jpg
#   inflating: cats/cats/9948.jpg
#   inflating: cats/cats/9949.jpg
#   inflating: cats/cats/995.jpg
#   inflating: cats/cats/9950.jpg
#   inflating: cats/cats/9951.jpg
#   inflating: cats/cats/9952.jpg
#   inflating: cats/cats/9953.jpg
#   inflating: cats/cats/9954.jpg
#   inflating: cats/cats/9955.jpg
#   inflating: cats/cats/9956.jpg
#   inflating: cats/cats/9957.jpg
#   inflating: cats/cats/9958.jpg
#   inflating: cats/cats/9959.jpg
#   inflating: cats/cats/996.jpg
#   inflating: cats/cats/9960.jpg
#   inflating: cats/cats/9961.jpg
#   inflating: cats/cats/9962.jpg
#   inflating: cats/cats/9963.jpg
#   inflating: cats/cats/9964.jpg
#   inflating: cats/cats/9965.jpg
#   inflating: cats/cats/9966.jpg
#   inflating: cats/cats/9967.jpg
#   inflating: cats/cats/9968.jpg
#   inflating: cats/cats/9969.jpg
#   inflating: cats/cats/997.jpg
#   inflating: cats/cats/9970.jpg
#   inflating: cats/cats/9971.jpg
#   inflating: cats/cats/9972.jpg
#   inflating: cats/cats/9973.jpg
#   inflating: cats/cats/9974.jpg
#   inflating: cats/cats/9975.jpg
#   inflating: cats/cats/9976.jpg
#   inflating: cats/cats/9977.jpg
#   inflating: cats/cats/9978.jpg
#   inflating: cats/cats/9979.jpg
#   inflating: cats/cats/998.jpg
#   inflating: cats/cats/9980.jpg
#   inflating: cats/cats/9981.jpg
#   inflating: cats/cats/9982.jpg
#   inflating: cats/cats/9983.jpg
#   inflating: cats/cats/9984.jpg
#   inflating: cats/cats/9985.jpg
#   inflating: cats/cats/9986.jpg
#   inflating: cats/cats/9987.jpg
#   inflating: cats/cats/9988.jpg
#   inflating: cats/cats/9989.jpg
#   inflating: cats/cats/999.jpg
#   inflating: cats/cats/9990.jpg
#   inflating: cats/cats/9991.jpg
#   inflating: cats/cats/9992.jpg
#   inflating: cats/cats/9993.jpg
#   inflating: cats/cats/9994.jpg
#   inflating: cats/cats/9995.jpg
#   inflating: cats/cats/9996.jpg
#   inflating: cats/cats/9997.jpg
#   inflating: cats/cats/9998.jpg
#   inflating: cats/cats/9999.jpg

# %%
# !ls
# Out:
# archive.zip  cats  sample_data

# %%
DATA_DIR = './cats/'

# %%
image_size = 64
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %% [markdown]
# Подготовим наши изображения к дальнейшему использованию

# %%
train_ds = ImageFolder(DATA_DIR, transform=tt.Compose([
    tt.Resize(image_size),
    tt.CenterCrop(image_size),
    tt.ToTensor(),
    tt.Normalize(*stats)]))

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %% [markdown]
# Посмотрим, как выглядит батч

# %%
show_batch(train_dl)

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %% [markdown]
# Давайте перейдем непосредственно к построению GANа. Напомним, что GAN состоит из двух сетей: *генератора*, задача которого – научиться генерировать изображения, похожие на обучающую выборку, из случайного шума, и *дискриминатора*, который учится распознавать, настоящее это изображение или сгенерированное генератором.
#
# Построим генератор и дискриминатор на свертках:

# %%
discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
discriminator = to_device(discriminator, device)

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

# %% [markdown]
# Посмотрим, как выглядит шум, из которого будут генерироваться изображения

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) 
print(xb.shape)
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 128, 1, 1])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-0f2f3ab1b261> in <module>()
#       1 xb = torch.randn(batch_size, latent_size, 1, 1)
#       2 print(xb.shape)
# ----> 3 fake_images = generator(xb)
#       4 print(fake_images.shape)
#       5 show_images(fake_images)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     840         return F.conv_transpose2d(
#     841             input, self.weight, self.bias, self.stride, self.padding,
# --> 842             output_padding, self.groups, self.dilation)
#     843
#     844
#
# RuntimeError: Tensor for argument #1 'input' is on CPU, Tensor for argument #2 'output' is on CPU, but expected them to be on GPU (while checking arguments for slow_conv_transpose2d_out_cuda)

# %%
generator = to_device(generator, device)

# %%
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
# !ls
# Out:
# archive.zip  cats  generated  sample_data

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %% [markdown]
# Перейдем теперь к обучению нашего GANа. Алгоритм обучения следующий:
# 1. Учим дискриминатор:
#   * берем реальные изображения и присваиваем им метку 1
#   * генерируем изображения генератором и присваиваем им метку 0
#   * обучаем классификатор на два класса
#
# 2. Учим генератор:
#   * генерируем изображения генератором и присваиваем им метку 0
#   * предсказываем дискриминаторором, реальное это изображение или нет
#
#
# В качестве функции потерь берем бинарную кросс-энтропию

# %%
def fit(model, criterion, epochs, lr, start_idx=1):
    model["discriminator"].train()
    model["generator"].train()
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    optimizer = {
        "discriminator": torch.optim.Adam(model["discriminator"].parameters(), 
                                          lr=lr, betas=(0.5, 0.999)),
        "generator": torch.optim.Adam(model["generator"].parameters(),
                                      lr=lr, betas=(0.5, 0.999))
    }
    
    for epoch in range(epochs):
        loss_d_per_epoch = []
        loss_g_per_epoch = []
        real_score_per_epoch = []
        fake_score_per_epoch = []
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            # Clear discriminator gradients
            optimizer["discriminator"].zero_grad()

            # Pass real images through discriminator
            real_preds = model["discriminator"](real_images)
            real_targets = torch.ones(real_images.size(0), 1, device=device)
            real_loss = criterion["discriminator"](real_preds, real_targets)
            cur_real_score = torch.mean(real_preds).item()
            
            # Generate fake images
            latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = model["generator"](latent)

            # Pass fake images through discriminator
            fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
            fake_preds = model["discriminator"](fake_images)
            fake_loss = criterion["discriminator"](fake_preds, fake_targets)
            cur_fake_score = torch.mean(fake_preds).item()

            real_score_per_epoch.append(cur_real_score)
            fake_score_per_epoch.append(cur_fake_score)

            # Update discriminator weights
            loss_d = real_loss + fake_loss
            loss_d.backward()
            optimizer["discriminator"].step()
            loss_d_per_epoch.append(loss_d.item())


            # Train generator
            # Clear generator gradients
            optimizer["generator"].zero_grad()
            
            # Generate fake images
            latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = model["generator"](latent)
            
            # Try to fool the discriminator
            preds = model["discriminator"](fake_images)
            targets = torch.ones(batch_size, 1, device=device)
            loss_g = criterion["generator"](preds, targets)
            
            # Update generator weights
            loss_g.backward()
            optimizer["generator"].step()
            loss_g_per_epoch.append(loss_g.item())
            
        # Record losses & scores
        losses_g.append(np.mean(loss_g_per_epoch))
        losses_d.append(np.mean(loss_d_per_epoch))
        real_scores.append(np.mean(real_score_per_epoch))
        fake_scores.append(np.mean(fake_score_per_epoch))
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, 
            losses_g[-1], losses_d[-1], real_scores[-1], fake_scores[-1]))
    
        # Save generated images
        if epoch == epochs - 1:
          save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
model = {
    "discriminator": discriminator.to(device),
    "generator": generator.to(device)
}

criterion = {
    "discriminator": nn.BCELoss(),
    "generator": nn.BCELoss()
}
lr = 0.0002
epochs = 40

# %%
history = fit(model, criterion, epochs, lr)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [1/40], loss_g: 7.1722, loss_d: 0.5180, real_score: 0.8217, fake_score: 0.1730
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [2/40], loss_g: 4.4419, loss_d: 0.5599, real_score: 0.8105, fake_score: 0.1885
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [3/40], loss_g: 3.7545, loss_d: 0.6862, real_score: 0.7661, fake_score: 0.2354
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [4/40], loss_g: 4.0141, loss_d: 0.7246, real_score: 0.7537, fake_score: 0.2374
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [5/40], loss_g: 4.2671, loss_d: 0.8204, real_score: 0.7441, fake_score: 0.2611
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [6/40], loss_g: 4.3659, loss_d: 0.7707, real_score: 0.7507, fake_score: 0.2451
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [7/40], loss_g: 4.5590, loss_d: 0.6535, real_score: 0.7786, fake_score: 0.2240
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [8/40], loss_g: 4.5356, loss_d: 0.7183, real_score: 0.7691, fake_score: 0.2228
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [9/40], loss_g: 4.2952, loss_d: 0.7277, real_score: 0.7648, fake_score: 0.2354
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [10/40], loss_g: 4.4053, loss_d: 0.6689, real_score: 0.7806, fake_score: 0.2206
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [11/40], loss_g: 4.2916, loss_d: 0.7150, real_score: 0.7706, fake_score: 0.2217
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [12/40], loss_g: 4.2637, loss_d: 0.7063, real_score: 0.7701, fake_score: 0.2370
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [13/40], loss_g: 4.3633, loss_d: 0.6477, real_score: 0.7891, fake_score: 0.2057
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [14/40], loss_g: 4.4564, loss_d: 0.6242, real_score: 0.7943, fake_score: 0.2012
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [15/40], loss_g: 4.3925, loss_d: 0.6807, real_score: 0.7893, fake_score: 0.2132
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [16/40], loss_g: 4.2689, loss_d: 0.5296, real_score: 0.8158, fake_score: 0.1838
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [17/40], loss_g: 4.5476, loss_d: 0.5424, real_score: 0.8229, fake_score: 0.1768
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [18/40], loss_g: 4.6541, loss_d: 0.5855, real_score: 0.8191, fake_score: 0.1774
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [19/40], loss_g: 4.6868, loss_d: 0.4590, real_score: 0.8414, fake_score: 0.1595
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [20/40], loss_g: 4.7630, loss_d: 0.5483, real_score: 0.8324, fake_score: 0.1622
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [21/40], loss_g: 4.6379, loss_d: 0.5033, real_score: 0.8356, fake_score: 0.1620
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [22/40], loss_g: 4.8609, loss_d: 0.5233, real_score: 0.8414, fake_score: 0.1573
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [23/40], loss_g: 4.8510, loss_d: 0.4776, real_score: 0.8529, fake_score: 0.1507
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [24/40], loss_g: 4.9610, loss_d: 0.4091, real_score: 0.8679, fake_score: 0.1290
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [25/40], loss_g: 5.2065, loss_d: 0.4246, real_score: 0.8677, fake_score: 0.1334
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [26/40], loss_g: 5.0668, loss_d: 0.4037, real_score: 0.8708, fake_score: 0.1258
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [27/40], loss_g: 5.6685, loss_d: 0.3064, real_score: 0.8963, fake_score: 0.1035
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [28/40], loss_g: 5.3861, loss_d: 0.3698, real_score: 0.8798, fake_score: 0.1188
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [29/40], loss_g: 5.4172, loss_d: 0.3715, real_score: 0.8853, fake_score: 0.1147
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [30/40], loss_g: 5.5339, loss_d: 0.4375, real_score: 0.8781, fake_score: 0.1197
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [31/40], loss_g: 5.3304, loss_d: 0.4346, real_score: 0.8700, fake_score: 0.1311
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [32/40], loss_g: 5.6181, loss_d: 0.2514, real_score: 0.9226, fake_score: 0.0862
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [33/40], loss_g: 5.7301, loss_d: 0.3778, real_score: 0.8876, fake_score: 0.1019
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [34/40], loss_g: 5.5976, loss_d: 0.3285, real_score: 0.8987, fake_score: 0.1001
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [35/40], loss_g: 5.6668, loss_d: 0.3072, real_score: 0.9029, fake_score: 0.0992
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [36/40], loss_g: 5.9960, loss_d: 0.2783, real_score: 0.9129, fake_score: 0.0876
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [37/40], loss_g: 6.1598, loss_d: 0.2522, real_score: 0.9145, fake_score: 0.0783
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [38/40], loss_g: 5.9173, loss_d: 0.3210, real_score: 0.9044, fake_score: 0.1020
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [39/40], loss_g: 6.0125, loss_d: 0.2849, real_score: 0.9130, fake_score: 0.0882
# HBox(children=(FloatProgress(value=0.0, max=124.0), HTML(value='')))
# Epoch [40/40], loss_g: 6.2676, loss_d: 0.2679, real_score: 0.9245, fake_score: 0.0753
# Saving generated-images-0040.png

# %% [markdown]
# Посмотрим на результаты обучения. Вот так выглядят котики, сгенерированные на последней эпохе обучения:

# %%
losses_g, losses_d, real_scores, fake_scores = history

# %%
generated_img = cv2.imread(f'./generated/generated-images-00{epochs}.png')
generated_img = generated_img[:, :, [2, 1, 0]]

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xticks([]); ax.set_yticks([])
ax.imshow(generated_img)

# %% [markdown]
# Как мы видим, изображение в целом получается похожим, однако есть много артефактов

# %% [markdown]
# Посмотрим на графики loss генератора и дискриминатора и score дискриминатора

# %%
plt.figure(figsize=(15, 6))
plt.plot(losses_d, '-')
plt.plot(losses_g, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.figure(figsize=(15, 6))

plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real', 'Fake'])
plt.title('Scores');

# %% [markdown]
# Поведение графиков примерно такое же, как было показано на лекции
